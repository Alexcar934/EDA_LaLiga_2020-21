# %%
import pandas as pd

data1 = pd.read_csv('/Users/alexcar934/Desktop/EDA_bien/src/data/processed/csv_plots/1_Pases_Regates.csv')
equipos = pd.read_csv('/Users/alexcar934/Desktop/EDA_bien/src/data/processed/csv_principales/5_Mediocentros.csv')
equipos = equipos[['Jugador', 'Equipo']]
data_pr = data1.merge(equipos, how='inner', on='Jugador')
data_pr = data_pr.iloc[:,1:]
data_pr
# Out:
#              Jugador    Regates  Pases Acertados      Equipo
# 0        Luka Modrić  20.330556       652.141667       RealM
# 1       Renato Tapia  12.862500       538.387500       Celta
# 2       Mikel Merino  10.775000       492.956250       RealS
# 3       Denis Suárez   8.818056       309.891667       Celta
# 4             Nolito   8.708333       217.708333       Celta
# 5    Guido Rodríguez   7.826389       457.843750       Betis
# 6    Frenkie de Jong   7.136111       267.604167   Barcelona
# 7       Edu Expósito   6.581250       255.937500       Eibar
# 8     Pedro Mosquera   6.557639       662.321528      Huesca
# 9     Gonzalo Melero   6.437500       305.781250     Levante
# 10       David Silva   6.383333       219.693056       RealS
# 11    Manu Trigueros   6.248611       273.802778  Villarreal
# 12  William Carvalho   5.675000       385.900000       Betis
# 13     Daniel Parejo   5.394444       530.004167  Villarreal
# ...

# %%
data_pr.to_csv('/Users/alexcar934/Desktop/EDA_bien/src/data/processed/csv_plots/1_Pases_Regates_Equipo.csv')
